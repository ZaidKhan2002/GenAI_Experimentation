# %% [markdown]
# <a href="https://colab.research.google.com/github/ZaidKhan2002/GenAI_Experimentation/blob/main/LangGraph_Product_Description_Annotated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LangGraph Agentic Workflow: Product Description Generator
#
# This notebook demonstrates how to build an **agentic workflow** using LangGraph.
#
# Instead of asking one LLM prompt to perform the entire task, we divide the work into smaller steps. Each step performs one responsibility, stores its result in a shared state, and passes control to the next step.
#
# ## What students will learn
#
# - What LangGraph is and why it is useful
# - How **state** carries data through a workflow
# - How **nodes** perform individual tasks
# - How **edges** control the direction of execution
# - How to build sequential, parallel, conditional, and looping workflows
# - How multiple AI steps can work together like a team of specialized agents

# %%
# !pip install -U langgraph langchain langchain-core langchain-community \
               langchain-openai langchain-experimental \
               pydantic typing-extensions
# Out:
# Requirement already satisfied: langgraph in /usr/local/lib/python3.13/dist-packages (1.2.11)
# Requirement already satisfied: langchain in /usr/local/lib/python3.13/dist-packages (1.3.15)
# Collecting langchain
#   Downloading langchain-1.3.16-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: langchain-core in /usr/local/lib/python3.13/dist-packages (1.5.5)
# Collecting langchain-core
#   Downloading langchain_core-1.6.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting langchain-community
#   Downloading langchain_community-0.4.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting langchain-openai
#   Downloading langchain_openai-1.6.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting langchain-experimental
#   Downloading langchain_experimental-0.4.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.13/dist-packages (2.13.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.13/dist-packages (4.16.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /usr/local/lib/python3.13/dist-packages (from langgraph) (4.2.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from langgraph) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from langgraph) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.13/dist-packages (from langgraph) (4.0.1)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.13/dist-packages (from langchain-core) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.13/dist-packages (from langchain-core) (0.11.0)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core) (26.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core) (0.17.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (3.14.3)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting langchain-classic<2.0.0,>=1.0.7 (from langchain-community)
#   Downloading langchain_classic-1.0.8-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy>=2.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (2.1.3)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community)
#   Downloading pydantic_settings-2.15.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting requests<3.0.0,>=2.32.5 (from langchain-community)
#   Downloading requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (2.0.52)
# Requirement already satisfied: certifi>=2024.6.2 in /usr/local/lib/python3.13/dist-packages (from langchain-openai) (2026.7.22)
# Requirement already satisfied: openai<4.0.0,>=2.45.0 in /usr/local/lib/python3.13/dist-packages (from langchain-openai) (2.54.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /usr/local/lib/python3.13/dist-packages (from langchain-openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic) (0.4.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.5)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (4.14.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.13/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.1.1)
# Collecting langchain-text-splitters<2.0.0,>=1.1.2 (from langchain-classic<2.0.0,>=1.0.7->langchain-community)
#   Downloading langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.13/dist-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in /usr/local/lib/python3.13/dist-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (3.12.0)
# Requirement already satisfied: websockets<16,>=14 in /usr/local/lib/python3.13/dist-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (15.0.1)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.13/dist-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (0.16.0)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.13/dist-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (4.67.3)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.13/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.13/dist-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.13/dist-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.11.3)
# Downloading langchain-1.3.16-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 4.7 MB/s eta 0:00:00
# Downloading langchain_core-1.6.0-py3-none-any.whl (570 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.0/570.0 kB 17.7 MB/s eta 0:00:00
# Downloading langchain_community-0.4.2-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 46.0 MB/s eta 0:00:00
# Downloading langchain_openai-1.6.0-py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.1/125.1 kB 6.0 MB/s eta 0:00:00
# Downloading langchain_experimental-0.4.2-py3-none-any.whl (211 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.2/211.2 kB 7.9 MB/s eta 0:00:00
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading langchain_classic-1.0.8-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 27.9 MB/s eta 0:00:00
# Downloading pydantic_settings-2.15.0-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 2.1 MB/s eta 0:00:00
# Downloading requests-2.34.2-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 3.3 MB/s eta 0:00:00
# Downloading langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Installing collected packages: requests, httpx-sse, pydantic-settings, langchain-core, langchain-text-splitters, langchain-openai, langchain-classic, langchain-community, langchain-experimental, langchain
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.5.5
#     Uninstalling langchain-core-1.5.5:
#       Successfully uninstalled langchain-core-1.5.5
#   Attempting uninstall: langchain
#     Found existing installation: langchain 1.3.15
#     Uninstalling langchain-1.3.15:
#       Successfully uninstalled langchain-1.3.15
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# Successfully installed httpx-sse-0.4.3 langchain-1.3.16 langchain-classic-1.0.8 langchain-community-0.4.2 langchain-core-1.6.0 langchain-experimental-0.4.2 langchain-openai-1.6.0 langchain-text-splitters-1.1.2 pydantic-settings-2.15.0 requests-2.34.2

# %%
# -----------------------------------------
# Imports
# -----------------------------------------
from typing_extensions import TypedDict
from langgraph.graph import StateGraph, START, END
from dotenv import load_dotenv
import os

from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage

# %%
import os
import getpass

os.environ["OPENROUTER_API_KEY"] = getpass.getpass("Enter OpenRouter API Key: ")
OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")
# Out:
# Enter OpenRouter API Key: ··········

# %% [markdown]
# ## 1. Shared State: The Workflow's Memory
#
# A LangGraph workflow needs a common data structure called **state**.
#
# Think of the state as a shared notebook carried through the graph. Every node can:
#
# 1. Read information already stored in the state
# 2. Perform its task
# 3. Return one or more updated state values
#
# In this example, the state begins with a product name. As the graph runs, each node adds new information such as the basic description, features, marketing message, and final description.
#
# ```text
# Initial State
#     ↓
# product_name = "Smart Water Bottle"
#     ↓
# Nodes gradually fill the remaining fields
# ```
#
# `TypedDict` describes which keys are expected in the state and the type of value stored under each key.

# %%
# -----------------------------------------
# LLM (OpenRouter)
# -----------------------------------------
llm = ChatOpenAI(
    model="openai/gpt-4o-mini",
    temperature=0.3,
    max_tokens = 300,
    openai_api_key=OPENROUTER_API_KEY,
    base_url="https://openrouter.ai/api/v1"
)

# -----------------------------------------
# Graph State
# -----------------------------------------
class State(TypedDict):
    product_name: str
    basic_description: str
    features_benefits: str
    marketing_message: str
    final_description: str

# %% [markdown]
# ## 2. Nodes: The Workers of the Graph
#
# A **node** is a Python function that performs one specific step in the workflow.
#
# Each node:
#
# - Receives the current state
# - Reads the data it needs
# - Performs an operation, such as calling an LLM
# - Returns a dictionary containing updated state fields
#
# For example:
#
# ```python
# def generate_basic_description(state: State):
#     ...
#     return {"basic_description": response.content}
# ```
#
# This node reads `product_name` and writes its result into `basic_description`.
#
# | Node name | Python function | Responsibility |
# |---|---|---|
# | `basic` | `generate_basic_description` | Creates the first product description |
# | `features` | `add_features_benefits` | Extracts features and benefits |
# | `marketing` | `create_marketing_message` | Produces persuasive marketing copy |
# | `final` | `polish_final_description` | Produces the polished final output |
#
# The node name is the label used inside the graph. The function contains the actual task logic.

# %%
# -----------------------------------------
# Nodes
# -----------------------------------------

def generate_basic_description(state: State):
    response = llm.invoke([
      SystemMessage(content="You are a helpful assistant that generates brief product descriptions."),
        HumanMessage(content=f"Write a brief description of a product named '{state['product_name']}'.")
    ])
    return {"basic_description": response.content}


def add_features_benefits(state: State):
    response = llm.invoke([
        HumanMessage(content=f"List key features and benefits of the product:\n{state['basic_description']}")
    ])
    return {"features_benefits": response.content}


def create_marketing_message(state: State):
    response = llm.invoke([
        HumanMessage(content=f"Create a compelling marketing message using:\n{state['features_benefits']}")
    ])
    return {"marketing_message": response.content}


def polish_final_description(state: State):
    response = llm.invoke([
        HumanMessage(content=f"""
Polish and finalize the product description using the marketing message below:

{state['marketing_message']}
""")
    ])
    return {"final_description": response.content}

# %% [markdown]
# ## 3. Edges: The Routes Between Nodes
#
# An **edge** tells LangGraph which node should run next.
#
# Think of nodes as cities and edges as roads connecting them.
#
# ```text
# START → basic → features → marketing → final → END
# ```
#
# ### Normal edge
#
# ```python
# workflow.add_edge("basic", "features")
# ```
#
# After `basic` finishes, LangGraph runs `features`.
#
# ### START edge
#
# ```python
# workflow.add_edge(START, "basic")
# ```
#
# `START` is the special entry point of the graph.
#
# ### END edge
#
# ```python
# workflow.add_edge("final", END)
# ```
#
# `END` tells LangGraph to stop and return the final state.
#
# ### Building the workflow
#
# - `StateGraph(State)` creates a graph using the defined state
# - `add_node()` registers a function as a graph step
# - `add_edge()` connects graph steps
# - `compile()` validates the graph and makes it executable

# %%
# -----------------------------------------
# Build LangGraph Workflow
# -----------------------------------------
def build_workflow():
    workflow = StateGraph(State)

    workflow.add_node("basic", generate_basic_description)
    workflow.add_node("features", add_features_benefits)
    workflow.add_node("marketing", create_marketing_message)
    workflow.add_node("final", polish_final_description)

    workflow.add_edge(START, "basic")
    workflow.add_edge("basic", "features")
    workflow.add_edge("features", "marketing")
    workflow.add_edge("marketing", "final")
    workflow.add_edge("final", END)

    return workflow.compile()

# %% [markdown]
# ## 4. Running the Sequential Graph
#
# `app.invoke(initial_state)` starts the graph.
#
# LangGraph then:
#
# 1. Sends the initial state to `basic`
# 2. Merges the returned update into the shared state
# 3. Follows the edge to the next node
# 4. Continues until it reaches `END`
# 5. Returns the completed state as `result`
#
# A node normally returns only the fields it changes. LangGraph merges those updates into the existing state.

# %%
# -----------------------------------------
# Run
# -----------------------------------------
if __name__ == "__main__":
    app = build_workflow()

    initial_state: State = {
        "product_name": "Smart Water Bottle",
        "basic_description": "",
        "features_benefits": "",
        "marketing_message": "",
        "final_description": "",
    }

    result = app.invoke(initial_state)

    print("\n--- BASIC DESCRIPTION ---\n")
    print(result["basic_description"])

    print("\n--- FEATURES & BENEFITS ---\n")
    print(result["features_benefits"])

    print("\n--- MARKETING MESSAGE ---\n")
    print(result["marketing_message"])

    print("\n--- FINAL DESCRIPTION ---\n")
    print(result["final_description"])
# Out:
# --- BASIC DESCRIPTION ---
#
# The Smart Water Bottle is an innovative hydration companion designed to keep you on track with your daily water intake. Featuring a sleek, ergonomic design, this bottle syncs with a mobile app to monitor your hydration levels, set personalized goals, and send reminders to drink water throughout the day. Made from durable, BPA-free materials, it keeps your beverages at the perfect temperature while its built-in LED lights provide visual reminders. Stay healthy and hydrated effortlessly with the Smart Water Bottle!
#
# --- FEATURES & BENEFITS ---
#
# ### Key Features of the Smart Water Bottle:
#
# 1. **Mobile App Integration**: Syncs with a dedicated app to track hydration levels and set personalized water intake goals.
#
# 2. **Personalized Reminders**: Sends notifications and reminders to encourage regular water consumption throughout the day.
#
# 3. **Sleek Ergonomic Design**: Designed for comfortable handling and easy portability, making it convenient for daily use.
#
# 4. **Durable, BPA-Free Materials**: Constructed from high-quality, safe materials that ensure longevity and safety for your beverages.
#
# 5. **Temperature Control**: Maintains your drinks at the desired temperature, whether hot or cold.
#
# 6. **Built-in LED Lights**: Provides visual cues and reminders to drink water, enhancing user engagement.
#
# 7. **Hydration Tracking**: Monitors daily water intake and provides insights on hydration habits over time.
#
# 8. **Goal Setting**: Allows users to set and adjust hydration goals based on personal needs and lifestyle.
#
# 9. **User-Friendly Interface**: Intuitive app interface for easy navigation and tracking.
#
# 10. **Rechargeable Battery**: Equipped with a long-lasting battery that can be easily recharged.
#
# ### Benefits of the Smart Water Bottle:
#
# 1. **Promotes Healthy Hydration**: Encourages users to meet their daily hydration needs, contributing to overall health and wellness.
#
# 2. **Increases Awareness**: Helps users become more conscious of their drinking habits and hydration levels.
#
# 3. **Convenient and User
#
# --- MARKETING MESSAGE ---
#
# ### Stay Hydrated, Stay Healthy with the Smart Water Bottle!
#
# Are you ready to transform your hydration habits? Meet the Smart Water Bottle—the ultimate companion for your wellness journey!
#
# **Why Choose the Smart Water Bottle?**
#
# - **Mobile App Integration**: Seamlessly sync your bottle with our dedicated app to track your hydration levels and set personalized water intake goals tailored just for you.
#
# - **Personalized Reminders**: Never forget to drink water again! Our bottle sends you timely notifications to keep you on track throughout the day.
#
# - **Sleek Ergonomic Design**: With its stylish and comfortable design, the Smart Water Bottle is perfect for your daily adventures—whether at the gym, office, or on the go!
#
# - **Durable, BPA-Free Materials**: Crafted from high-quality, safe materials, our bottle ensures your beverages are not only safe but also stay fresh and delicious.
#
# - **Temperature Control**: Enjoy your drinks just the way you like them! Our innovative technology keeps your beverages hot or cold for hours.
#
# - **Built-in LED Lights**: Stay engaged with fun visual cues that remind you to hydrate, making drinking water an enjoyable experience.
#
# - **Hydration Tracking**: Gain insights into your drinking habits with our advanced monitoring system, helping you understand your hydration patterns over time.
#
# - **Goal Setting**: Customize your hydration goals based on your lifestyle, and watch as you achieve them with ease!
#
# - **User-Friendly Interface**: Navigate effortlessly through our intuitive
#
# --- FINAL DESCRIPTION ---
#
# app, making hydration management a breeze.
#
# ### Stay Hydrated, Stay Healthy with the Smart Water Bottle!
#
# Are you ready to revolutionize your hydration habits? Introducing the Smart Water Bottle—the ultimate companion for your wellness journey!
#
# **Why Choose the Smart Water Bottle?**
#
# - **Mobile App Integration**: Effortlessly sync your bottle with our dedicated app to monitor your hydration levels and set personalized water intake goals tailored just for you.
#
# - **Personalized Reminders**: Say goodbye to dehydration! Our bottle sends timely notifications to keep you on track and ensure you never forget to drink water again.
#
# - **Sleek Ergonomic Design**: With its stylish and comfortable design, the Smart Water Bottle is perfect for your daily adventures—whether you're at the gym, in the office, or on the go!
#
# - **Durable, BPA-Free Materials**: Crafted from high-quality, safe materials, our bottle guarantees that your beverages are not only safe but also stay fresh and delicious.
#
# - **Temperature Control**: Enjoy your drinks just the way you like them! Our innovative technology keeps your beverages hot or cold for hours, ensuring the perfect sip every time.
#
# - **Built-in LED Lights**: Stay engaged with fun visual cues that remind you to hydrate, transforming drinking water into an enjoyable experience.
#
# - **Hydration Tracking**: Gain valuable insights into your drinking habits with our advanced monitoring system, helping you understand your hydration patterns over time.
#
# - **Goal Setting**: Customize your hydration goals based

# %% [markdown]
# # Advanced LangGraph Flow: Parallel Branches and a Loop
#
# The second workflow demonstrates:
#
# - **Fan-out:** one node sends work to multiple nodes
# - **Parallel processing:** independent nodes handle separate tasks
# - **Fan-in:** multiple branches join at one node
# - **Conditional edge:** the next route depends on state
# - **Loop:** execution returns to an earlier step for improvement
#
# ```text
#                          ┌→ features ─┐
# START → basic description├→ audience ─┼→ marketing → final → evaluate
#                          └→ SEO ──────┘                    │
#                                                           ├→ END
#                                                           └→ improve → evaluate
# ```

# %%
# -----------------------------------------
# Imports
# -----------------------------------------
from typing_extensions import TypedDict
from langgraph.graph import StateGraph, START, END
from dotenv import load_dotenv
import os
import random

from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage

# -----------------------------------------
# Load API key
# -----------------------------------------
import os
import getpass

os.environ["OPENROUTER_API_KEY"] = getpass.getpass("Enter OpenRouter API Key: ")
OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")

llm = ChatOpenAI(
    model="openai/gpt-4o-mini",
    temperature=0.4,
    openai_api_key=os.getenv("OPENROUTER_API_KEY"),
    base_url="https://openrouter.ai/api/v1"
)
# Out:
# Enter OpenRouter API Key: ··········

# %% [markdown]
# ## 5. Parallel Nodes and Fan-Out
#
# After the basic description is created, three independent tasks begin:
#
# - Generate features and benefits
# - Identify the target audience
# - Generate SEO keywords
#
# ```python
# workflow.add_edge("basic", "features")
# workflow.add_edge("basic", "audience")
# workflow.add_edge("basic", "seo")
# ```
#
# This one-to-many branching pattern is called **fan-out**.
#
# Each branch updates a different state field:
#
# ```text
# features node  → features_benefits
# audience node  → target_audience
# seo node       → seo_keywords
# ```
#
# Parallel nodes should generally avoid writing to the same state key unless a reducer or merge strategy is configured.
#
# ## 6. Fan-In and the Merge Node
#
# The `marketing` node uses the outputs of all three branches.
#
# ```text
# features ─┐
# audience ─┼→ marketing
# SEO ──────┘
# ```
#
# This many-to-one pattern is called **fan-in**. The shared state allows the marketing node to read all three results together.

# %%
# -----------------------------------------
# State
# -----------------------------------------
class State(TypedDict):
    product_name: str
    basic_description: str
    features_benefits: str
    target_audience: str
    seo_keywords: str
    marketing_message: str
    final_description: str
    quality_score: int

# -----------------------------------------
# Nodes
# -----------------------------------------

def generate_basic_description(state: State):
    response = llm.invoke([
        SystemMessage(content="You generate short product descriptions."),
        HumanMessage(content=f"Write a brief description of '{state['product_name']}'.")
    ])
    return {"basic_description": response.content}


# ----------- PARALLEL NODES -----------

def add_features(state: State):
    response = llm.invoke(
        f"List key features and benefits:\n{state['basic_description']}"
    )
    return {"features_benefits": response.content}


def identify_audience(state: State):
    response = llm.invoke(
        f"Who is the ideal target audience for this product?\n{state['basic_description']}"
    )
    return {"target_audience": response.content}


def generate_seo_keywords(state: State):
    response = llm.invoke(
        f"Generate SEO keywords for this product:\n{state['basic_description']}"
    )
    return {"seo_keywords": response.content}


# ----------- MERGE NODE -----------

def create_marketing_message(state: State):
    combined = f"""
Features:
{state['features_benefits']}

Audience:
{state['target_audience']}

SEO:
{state['seo_keywords']}
"""
    response = llm.invoke(
        f"Create a compelling marketing message using:\n{combined}"
    )
    return {"marketing_message": response.content}

# %% [markdown]
# ## 7. Conditional Edges and Loops
#
# A normal edge always follows the same route. A **conditional edge** chooses the next route by checking the state.
#
# ```python
# lambda state: "improve" if state["quality_score"] < 6 else "end"
# ```
#
# This means:
#
# ```text
# score below 6 → improve the description
# score 6 or above → finish
# ```
#
# The improvement node connects back to evaluation:
#
# ```python
# workflow.add_edge("improve", "evaluate")
# ```
#
# This creates a loop:
#
# ```text
# evaluate → improve → evaluate
# ```
#
# Loops are useful for reflection, correction, validation, retries, and approval workflows.
#
# > This notebook uses a random quality score for demonstration. A real application could use an LLM evaluator, business rules, a validation model, or human feedback. Production loops should also have a maximum retry count.

# %%
# ----------- FINAL POLISH -----------

def polish_final_description(state: State):
    response = llm.invoke(
        f"Polish and finalize:\n{state['marketing_message']}"
    )
    return {"final_description": response.content}


# ----------- QUALITY CHECK (LOOP CONTROL) -----------

def evaluate_quality(state: State):
    """
    Simulated quality scoring.
    In real systems you'd use LLM scoring.
    """
    score = random.randint(4, 7)
    print(f"\nQuality Score: {score}")
    return {"quality_score": score}


def improve_description(state: State):
    response = llm.invoke(
        f"Improve this product description to make it more persuasive:\n{state['final_description']}"
    )
    return {"final_description": response.content}

# %% [markdown]
# ## 8. Reading the Advanced Graph Definition
#
# The graph is created in four stages:
#
# 1. Register nodes with `add_node()`
# 2. Connect `START` to the first node
# 3. Create parallel branches and merge them
# 4. Add conditional routing and the improvement loop
#
# A fixed route uses:
#
# ```python
# workflow.add_edge("marketing", "final")
# ```
#
# A dynamic route uses:
#
# ```python
# workflow.add_conditional_edges("evaluate", routing_function, route_map)
# ```
#
# The routing function inspects the state and returns a route name. The route map converts that name into a node or `END`.

# %%
# -----------------------------------------
# Build Graph
# -----------------------------------------
def build_workflow():
    workflow = StateGraph(State)
    # Nodes
    workflow.add_node("basic", generate_basic_description)
    workflow.add_node("features", add_features)
    workflow.add_node("audience", identify_audience)
    workflow.add_node("seo", generate_seo_keywords)
    workflow.add_node("marketing", create_marketing_message)
    workflow.add_node("final", polish_final_description)
    workflow.add_node("evaluate", evaluate_quality)
    workflow.add_node("improve", improve_description)
    # Flow
    workflow.add_edge(START, "basic")
    # ---- PARALLEL FAN OUT ----
    workflow.add_edge("basic", "features")
    workflow.add_edge("basic", "audience")
    workflow.add_edge("basic", "seo")
    # ---- FAN IN (merge) ----
    workflow.add_edge("features", "marketing")
    workflow.add_edge("audience", "marketing")
    workflow.add_edge("seo", "marketing")

    workflow.add_edge("marketing", "final")
    # ---- LOOP SECTION ----
    workflow.add_edge("final", "evaluate")
    workflow.add_conditional_edges(
        "evaluate",
        lambda state: "improve" if state["quality_score"] < 6 else "end",
        {
            "improve": "improve",
            "end": END
        }
    )
    workflow.add_edge("improve", "evaluate")
    return workflow.compile()

# %% [markdown]
# ## 9. How the State Grows
#
# For `"Smart Water Bottle"`, the state changes approximately like this:
#
# ```text
# Step 1: product_name
# Step 2: + basic_description
# Step 3: + features_benefits
#         + target_audience
#         + seo_keywords
# Step 4: + marketing_message
# Step 5: + final_description
# Step 6: + quality_score
# Step 7: improve and evaluate again, or stop
# ```
#
# The final `result` contains the complete state when the graph reaches `END`.

# %%
# -----------------------------------------
# Run
# -----------------------------------------
if __name__ == "__main__":
    app = build_workflow()

    initial_state: State = {
        "product_name": "Smart Water Bottle",
        "basic_description": "",
        "features_benefits": "",
        "target_audience": "",
        "seo_keywords": "",
        "marketing_message": "",
        "final_description": "",
        "quality_score": 0
    }

    result = app.invoke(initial_state)

    print("\nFINAL OUTPUT:\n")
    print(result["final_description"])
# Out:
# Quality Score: 5
#
# Quality Score: 7
#
# FINAL OUTPUT:
#
# ### Elevate Your Hydration Game: Meet the Revolutionary Smart Water Bottle!
#
# Are you constantly on the go and find it hard to remember to drink enough water? Do you want to unlock your full fitness potential through optimal hydration? Say hello to the **Smart Water Bottle**—your stylish, high-tech hydration partner designed to make staying hydrated effortless and enjoyable!
#
# #### Why You’ll Love It:
# - **Smart Water Intake Tracking**: Keep tabs on your daily water consumption with ease. Our bottle automatically records your intake, so you can focus on what really matters.
# - **Gentle Reminder Notifications**: Never forget to hydrate again! Receive friendly alerts that prompt you to take a sip, ensuring you stay on track throughout your busy day.
# - **Seamless Mobile App Integration**: Sync with our intuitive app for customized hydration goals and insightful analytics that empower you to take charge of your health.
# - **Chic, Modern Design**: This isn’t just a water bottle; it’s a fashion statement! Its sleek design complements any outfit, making it the perfect accessory for work, gym, or play.
# - **Safe and Sturdy**: Made from BPA-free materials, our water bottle is not only safe for you but also built to last, ensuring you have a reliable hydration solution for years to come.
# - **Built-in LED Indicators**: Stay motivated with visual reminders from our innovative LED lights, guiding you toward your hydration goals.
# - **User-Friendly Interface**: Navigate your hydration journey effortlessly with our easy-to-use app, designed for everyone—no tech skills required!
# - **Fitness Tracker Compatibility**: Integrate seamlessly with your favorite fitness apps and trackers for a holistic approach to health and wellness.
#
# #### Why Choose the Smart Water Bottle?
# - **Boost Your Health**: Regular hydration is key to overall wellness. Our Smart Water Bottle encourages you to drink more water, enhancing your energy levels and mental clarity.
# - **Tailored to You**: Enjoy a personalized hydration experience that adapts to your lifestyle, making it easier to stay accountable and motivated.
# - **Convenience for Busy Lives**: Perfect for professionals, students, and adventurers alike—this bottle is designed to fit into your fast-paced lifestyle.
# - **Stylish Meets Functional**: Look great while prioritizing your health. The Smart Water Bottle is the perfect blend of form and function.
# - **Eco-Friendly Choice**: With its durable, BPA-free construction, you’re not only investing in your health but also in the health of our planet.
# - **Maximize Your Fitness**: Proper hydration is essential for peak performance and faster recovery. Elevate your workouts and daily activities with the right hydration.
# - **Versatile for Everyone**: Whether you’re a fitness fanatic, a busy professional, or an outdoor explorer, this bottle is designed to meet your hydration needs.
# - **Built to Last**: Crafted for daily use, our Smart Water Bottle is your dependable hydration partner, ready for any adventure.
#
# #### Join the Hydration Revolution!
# Don’t let dehydration slow you down. Whether you’re crushing it at the gym, tackling a hectic workday, or enjoying nature, the **Smart Water Bottle** is your ultimate hydration ally. Experience the perfect fusion of cutting-edge technology and modern design today!
#
# **Order Yours Now!**
# Stay hydrated, stay healthy, and transform your hydration habits with the Smart Water Bottle—your body will thank you!
#
# ---
#
# ### SEO Keywords:
# - Smart Water Bottle
# - Hydration tracker
# - Water intake monitor
# - Personalized hydration goals
# - Mobile app water bottle
# - BPA-free water bottle
# - LED hydration reminders
# - Fitness water bottle
# - Modern design water bottle
# - Durable water bottle
# - Health and hydration
# - Hydration companion
# - Water bottle with app
# - Stay hydrated
# - Daily water intake reminder
# - Smart hydration solutions
# - Eco-friendly water bottle
# - Best water bottle for fitness
# - Hydration insights
# - Stylish water bottle for professionals
#
# ### Call to Action:
# Ready to revolutionize your hydration habits? **Order your Smart Water Bottle today and embark on the journey to a healthier, more vibrant you!**

# %% [markdown]
# ## 10. Gradio Interface
#
# The Gradio section provides a visual interface around the same compiled LangGraph workflow.
#
# When a user enters a product name:
#
# 1. Gradio creates the initial state
# 2. `app.invoke()` runs the graph
# 3. LangGraph returns the final state
# 4. Gradio displays the output produced by each node
#
# This helps students observe how a single input is transformed step by step.

# %%
# !pip install -q gradio

# %%
# =========================================================
# GRADIO UI FOR SECOND LANGGRAPH AGENTIC WORKFLOW
# Shows output of each agent/node step
# =========================================================



import gradio as gr

# Build the already-defined workflow
app = build_workflow()


def run_product_agent(product_name):
    initial_state: State = {
        "product_name": product_name,
        "basic_description": "",
        "features_benefits": "",
        "target_audience": "",
        "seo_keywords": "",
        "marketing_message": "",
        "final_description": "",
        "quality_score": 0
    }

    result = app.invoke(initial_state)

    basic = result.get("basic_description", "")
    features = result.get("features_benefits", "")
    audience = result.get("target_audience", "")
    seo = result.get("seo_keywords", "")
    marketing = result.get("marketing_message", "")
    final_description = result.get("final_description", "")
    quality_score = result.get("quality_score", "")

    process_view = f"""
# LangGraph Agentic Product Description Process

## 1. Basic Description Agent
{basic}

---

## 2. Features & Benefits Agent
{features}

---

## 3. Target Audience Agent
{audience}

---

## 4. SEO Keywords Agent
{seo}

---

## 5. Marketing Message Agent
{marketing}

---

## 6. Final Polish Agent
{final_description}

---

## 7. Quality Evaluation Agent
**Quality Score:** {quality_score}

---

## Final Output
{final_description}
"""

    return (
        basic,
        features,
        audience,
        seo,
        marketing,
        str(quality_score),
        final_description,
        process_view
    )


with gr.Blocks(title="LangGraph Product Description Agent") as demo:
    gr.Markdown("# LangGraph Product Description Agent")
    gr.Markdown(
        "Enter a product name and see how each LangGraph agent transforms it step by step."
    )

    with gr.Row():
        product_input = gr.Textbox(
            label="Product Name",
            value="Smart Water Bottle",
            placeholder="Enter product name..."
        )

    run_button = gr.Button("Generate Product Description")

    with gr.Tab("Step-by-Step Agent Outputs"):
        basic_output = gr.Textbox(
            label="1. Basic Description Agent",
            lines=6
        )

        features_output = gr.Textbox(
            label="2. Features & Benefits Agent",
            lines=8
        )

        audience_output = gr.Textbox(
            label="3. Target Audience Agent",
            lines=8
        )

        seo_output = gr.Textbox(
            label="4. SEO Keywords Agent",
            lines=6
        )

        marketing_output = gr.Textbox(
            label="5. Marketing Message Agent",
            lines=8
        )

        quality_output = gr.Textbox(
            label="6. Quality Score"
        )

        final_output = gr.Textbox(
            label="7. Final Product Description",
            lines=10
        )

    with gr.Tab("Full Process View"):
        full_process_output = gr.Markdown()

    run_button.click(
        fn=run_product_agent,
        inputs=product_input,
        outputs=[
            basic_output,
            features_output,
            audience_output,
            seo_output,
            marketing_output,
            quality_output,
            final_output,
            full_process_output
        ]
    )

demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://7665c729d818243e73.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://7665c729d818243e73.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
